# %%
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test['SalePrice'] = 0

# %%
df = pd.concat([train, test], ignore_index=True, sort=False)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 2914         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2915         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2916         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2917         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 2918         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                  0
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage    486
# LotArea          0
# ...            ...
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
# SalePrice        0
#
# [81 rows x 1 columns]

# %%
df[df[['MSZoning']].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1915  1916          30      NaN        109.0    21780   Grvl   NaN      Reg
# 2216  2217          20      NaN         80.0    14584   Pave   NaN      Reg
# 2250  2251          70      NaN          NaN    56600   Pave   NaN      IR1
# 2904  2905          20      NaN        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1915         Lvl       NaN  ...        0    NaN   NaN         NaN       0
# 2216         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 2250         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 2904         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1915      3   2009     ConLD         Normal          0
# 2216      2   2008        WD        Abnorml          0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()

# %%
train['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
def encode_MAS(df):
    if str(df) == 'BrkFace':
        return 0
    elif str(df) == 'None':
        return 1
    elif str(df) == 'Stone':
        return 2
    elif str(df) == 'BrkCmn':
        return 3
    else:
        return None

# %%
train['Mas_Type'] = train['MasVnrType'].apply(encode_MAS)

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
cormat = train.corr()

# %%
plt.figure(figsize=(30,30))
sns.heatmap(cormat, annot=True, cmap="RdYlGn")

# %%
top_f = list(cormat[cormat['SalePrice'] > 0.4]['SalePrice'].index)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(train[top_f].corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# # BaseLine

# %%
train = train[top_f]

# %%
train.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# 0            7       2003          2003       196.0          856       856
# 1            6       1976          1976         0.0         1262      1262
# 2            7       2001          2002       162.0          920       920
# 3            7       1915          1970         0.0          756       961
# 4            8       2000          2000       350.0         1145      1145
#
#    GrLivArea  FullBath  TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  \
# 0       1710         2             8           0       2003.0           2
# 1       1262         2             6           1       1976.0           2
# 2       1786         2             6           1       2001.0           2
# 3       1717         1             7           1       1998.0           3
# 4       2198         2             9           1       2000.0           3
#
#    GarageArea  SalePrice
# 0         548     208500
# ...

# %%
train.isnull().sum()/len(train)
# Out:
# OverallQual     0.000000
# YearBuilt       0.000000
# YearRemodAdd    0.000000
# MasVnrArea      0.000000
# TotalBsmtSF     0.000000
# 1stFlrSF        0.000000
# GrLivArea       0.000000
# FullBath        0.000000
# TotRmsAbvGrd    0.000000
# Fireplaces      0.000000
# GarageYrBlt     0.055479
# GarageCars      0.000000
# GarageArea      0.000000
# SalePrice       0.000000
# dtype: float64

# %%
# Impute Missing Values

# %%
train.describe()
# Out:
#        OverallQual    YearBuilt  YearRemodAdd   MasVnrArea  TotalBsmtSF  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      6.099315  1971.267808   1984.865753   103.685262  1057.429452
# std       1.382997    30.202904     20.645407   181.066207   438.705324
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000   795.750000
# 50%       6.000000  1973.000000   1994.000000     0.000000   991.500000
# 75%       7.000000  2000.000000   2004.000000   166.000000  1298.250000
# max      10.000000  2010.000000   2010.000000  1600.000000  6110.000000
#
#           1stFlrSF    GrLivArea     FullBath  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   1162.626712  1515.463699     1.565068      6.517808     0.613014
# std     386.587738   525.480383     0.550916      1.625393     0.644666
# ...

# %%
train.describe()
# Out:
#        OverallQual    YearBuilt  YearRemodAdd   MasVnrArea  TotalBsmtSF  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      6.099315  1971.267808   1984.865753   103.117123  1057.429452
# std       1.382997    30.202904     20.645407   180.731373   438.705324
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000   795.750000
# 50%       6.000000  1973.000000   1994.000000     0.000000   991.500000
# 75%       7.000000  2000.000000   2004.000000   164.250000  1298.250000
# max      10.000000  2010.000000   2010.000000  1600.000000  6110.000000
#
#           1stFlrSF    GrLivArea     FullBath  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   1162.626712  1515.463699     1.565068      6.517808     0.613014
# std     386.587738   525.480383     0.550916      1.625393     0.644666
# ...

# %%
sns.distplot(train['OverallQual'], bins=8)
# Check Binning bias
# Out:
# c:\programs files\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from scipy.stats import boxcox

# %%
sns.scatterplot(x="MasVnrArea", y="SalePrice", data=train)

# %%
train['MasVnrArea'] = train['MasVnrArea'].fillna(0)

# %%
b = boxcox(train['MasVnrArea']+0.1)[0]

# %%
sns.distplot(train['MasVnrArea'], bins=20, kde=False)
# What happens if predictor is skewed

# %%
sns.distplot(b)
# What happens if predictor is skewed
# Out:
# c:\programs files\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.scatterplot(x="GarageYrBlt", y="YearBuilt", data=train)
# Since the relation is linear and YrBlt causes GarageYrBlt, hence we can remove GarageYrBlt

# %%
top_f.remove("GarageYrBlt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-22548be31c6d> in <module>()
# ----> 1 top_f.remove("GarageYrBlt")
#
# ValueError: list.remove(x): x not in list

# %%
top_f.remove("SalePrice")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d089221db226> in <module>()
# ----> 1 top_f.remove("SalePrice")
#
# ValueError: list.remove(x): x not in list

# %%
train[top_f]
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# 0               7       2003          2003       196.0          856       856
# 1               6       1976          1976         0.0         1262      1262
# 2               7       2001          2002       162.0          920       920
# 3               7       1915          1970         0.0          756       961
# 4               8       2000          2000       350.0         1145      1145
# ...           ...        ...           ...         ...          ...       ...
# 1455            6       1999          2000         0.0          953       953
# 1456            6       1978          1988       119.0         1542      2073
# 1457            7       1941          2006         0.0         1152      1188
# 1458            5       1950          1996         0.0         1078      1078
# 1459            5       1965          1965         0.0         1256      1256
#
# ...

# %%
from sklearn.linear_model import LinearRegression
import xgboost as xgb 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
lr = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1, 
                          max_depth = 5, alpha = 10, n_estimators = 100)

# %%
X_train, X_test, y_train, y_test = train_test_split(train[top_f], train['SalePrice'], test_size=0.33, random_state=42)

# %%
# lr = LinearRegression()
# lr = RandomForestRegressor(n_estimators=100)

# %%
lr.fit(X_train, y_train)
# Out:
# c:\programs files\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.3, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)

# %%
y_pred = lr.predict(X_test)

# %%
X_test['y_test'] = y_test

# %%
X_test['y_pred'] = y_pred

# %%
X_test
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# 892             6       1963          2003         0.0         1059      1068
# 1105            8       1994          1995       362.0         1463      1500
# 413             5       1927          1950         0.0         1008      1028
# 522             6       1947          1950         0.0         1004      1004
# 1036            9       2007          2008        70.0         1620      1620
# ...           ...        ...           ...         ...          ...       ...
# 1010            5       1948          1950         0.0          720       720
# 390             5       1900          1950         0.0          861       961
# 1409            7       1986          1991       123.0          791      1236
# 847             5       1972          1972         0.0          864       864
# 1284            6       1919          1990         0.0          804      1699
#
# ...

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 36596.85721906633

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test[top_f].isnull().sum()
# Out:
# OverallQual     0
# YearBuilt       0
# YearRemodAdd    0
# MasVnrArea      0
# TotalBsmtSF     0
# 1stFlrSF        0
# GrLivArea       0
# FullBath        0
# TotRmsAbvGrd    0
# Fireplaces      0
# GarageCars      0
# GarageArea      0
# dtype: int64

# %%
test[top_f].describe()
# Out:
#        OverallQual    YearBuilt  YearRemodAdd   MasVnrArea  TotalBsmtSF  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean      6.078821  1971.357779   1983.662783    99.673749  1046.078136
# std       1.436812    30.390071     21.130467   177.001792   442.749327
# min       1.000000  1879.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1953.000000   1963.000000     0.000000   784.000000
# 50%       6.000000  1973.000000   1992.000000     0.000000   988.000000
# 75%       7.000000  2001.000000   2004.000000   162.000000  1304.000000
# max      10.000000  2010.000000   2010.000000  1290.000000  5095.000000
#
#           1stFlrSF    GrLivArea     FullBath  TotRmsAbvGrd  Fireplaces  \
# count  1459.000000  1459.000000  1459.000000   1459.000000  1459.00000
# mean   1156.534613  1486.045922     1.570939      6.385195     0.58122
# std     398.165820   485.566099     0.555190      1.508895     0.64742
# ...

# %%
test['MasVnrArea'] = test['MasVnrArea'].fillna(0)

# %%
test['GarageCars'] = test['GarageCars'].fillna(test['GarageCars'].median())

# %%
test['GarageArea'] = test['GarageArea'].fillna(test['GarageArea'].median())

# %%
test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].median())

# %%
lr.predict(test[top_f])
# Out:
# array([126969.56, 152225.86, 177599.  , ..., 169385.22, 116364.01,
#        229381.12], dtype=float32)

# %%
test['SalePrice'] = lr.predict(test[top_f])

# %%
test[['Id', 'SalePrice']].to_csv('ss_3.csv', index=False)
