# %%
import pandas as pd

# %%
df = pd.read_excel('AirQualityUCI.xlsx')

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df.tail(20)
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 9337 2005-04-03  19:00:00     2.7      1248.00      -200  11.109658
# 9338 2005-04-03  20:00:00     2.5      1180.25      -200   7.868564
# 9339 2005-04-03  21:00:00     1.5      1101.75      -200   5.999005
# 9340 2005-04-03  22:00:00     1.6      1115.50      -200   5.817660
# 9341 2005-04-03  23:00:00     1.2      1099.75      -200   5.106145
# 9342 2005-04-04  00:00:00     0.9      1012.00      -200   3.504006
# 9343 2005-04-04  01:00:00     0.6       944.25      -200   1.931932
# 9344 2005-04-04  02:00:00     0.5       911.75      -200   1.489323
# 9345 2005-04-04  03:00:00     0.4       887.00      -200   1.086365
# 9346 2005-04-04  04:00:00  -200.0       864.25      -200   0.801504
# 9347 2005-04-04  05:00:00     0.5       888.25      -200   1.307608
# 9348 2005-04-04  06:00:00     1.1      1030.50      -200   4.359341
# 9349 2005-04-04  07:00:00     4.0      1383.50      -200  17.364240
# ...
